# %% [markdown]
# Q1. What is Statistics?
# =>   Statistics is science of Collecting,organizing and summurazing of data
#
#
# Q2. Define the different types of statistics and give an example of when each type might be used.
# =>  There are two types of statistics
#         - Descriptive: Discrite stat used to organize and summerize data
#         - inferential: Inferential stats used to prediction of data
#
# Q3. What are the different types of data and how do they differ from each other? Provide an example of
# each type of data
# => There are two types of data
#
# 1.quantative: It reprasents numarical values.it also have two types  --
#         A. Discrit: It reprasents whole numbers. ex- no of phone of a person.
#         B. Conuntinues: It reprasents float and integer no .ex- weight of a boy.
#
# 2.Qualative : It reprasents catagorical features.    it also have two types --
#         A. Nominal: it is catagorical data use for labaling of data without values. ex-Gender
#         B. Odinal : Odinal data also a caagorical data but their are spacific order or rank among the catagorical values.
#
# Q4. Categorise the following datasets with respect to quantitative and qualitative data types:
# =>
# (i) Grading in exam: A+, A, B+, B, C+, C, D, E =Qalatative ordinal
# (ii) Colour of mangoes: yellow, green, orange, red =Qalative nominal
# (iii) Height data of a class: [178.9, 179, 179.5, 176, 177.2, 178.3, 175.8,...] == quantative Conuntinues
# (iv) Number of mangoes exported by a farm: [500, 600, 478, 672, ... == quantative discrit
#
# Q5. Explain the concept of levels of measurement and give an example of a variable for each level.
# =>
# A. Nominal : This is a basic level of measurment, variabeles are catagoeize without values.
#  ex- Gender
#
# B. Odinal: only order matters in this level of measurments but value not.
# ex -exam grade A+,A,B,C
#
# C.Interval: order of the variable matters but also diffrance between variables matter. '0' can't be present likely range/
# ex- temprature can be 30 c and -2 c
#
# C.Ratio:  order of the variable matters and diffrance between variables mattes. it start from 0.
# ex- Age
#
# Q6. Why is it important to understand the level of measurement when analyzing data? Provide an
# example to illustrate your answer
# => If we can't which kind of of data we deal with we can't perfrom any opration statistical analysis or  on it .
#
# ex-  grade levels have a natural order (e.g., 1st grade, 2nd grade, etc.), the numerical difference between grade levels is not consistent or meaningful. Treating grade levels as interval or ratio data and calculating measures such as the mean or standard deviation would be inappropriate because they imply quantitative differences between grades that don't exist.
#
# Q7. How nominal data type is different from ordinal data type.
# => Nominal : This is a basic level of measurment, variabeles are catagoeize without values.
#  ex- Gender
#
# Odinal: only order matters in this level of measurments but value not.
# ex -exam grade A+,A,B,C
#
# Q8. Which type of plot can be used to display data in terms of range?
# => HistoGram
#
# Q9. Describe the difference between descriptive and inferential statistics. Give an example of each
# type of statistics and explain how they are used.=>
# Descriptive Statistics:
# Descriptive statistics involve methods for summarizing and describing the characteristics of a dataset
# ex- Mean, median, mode, standard deviation, range
#
# Inferential Statistics:
# Inferential statistics involve methods for makingr predictions about a population based on a sample of dat.
#
#
# Q10. What are some common measures of central tendency and variability used in statistics? Explain
# how each measure can be used to describe a datase
# =>
# Measures of Central Tendency:
# 1.mean: exam scores mean  provides a measure of the average performance of the students in class.t
# 2.Median:  income represents the income level at which half of the households earn more and half earn less.
#
# 3.Mode: how many people like red color
# .Measures of Variability:
# 1.Range: highest and lowest  marks in exam
# 2.Variance:
# 3.Standard Deviation:
#
#
# .
# .].
