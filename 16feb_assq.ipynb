# %% [markdown]
# # Q1. What is a database? Differentiate between SQL and NoSQL databases.

# %% [raw]
# A database is an organized collection of structured  data, typically stored electronically in a computer system. Databases are managed by Database Management Systems (DBMS), which allow for the efficient storage, retrieval, and manipulation of data
#
# SQL (Structured Query Language) Databases and NoSQL (Not Only SQL) Databases are two broad categories of databases, each with distinct characteristics and use cases.
#
# SQL databases use a predefined schema to define the structure of the data. Tables, rows, and columns are used to store data.
# NoSQL databases do not require a fixed schema. They allow for flexible and dynamic data structures.Supports different data models such as key-value pairs, document-oriented, column-family, and graph-based.

# %% [markdown]
# # Q2. What is DDL? Explain why CREATE, DROP, ALTER, and TRUNCATE are used with an example.

# %% [raw]
# 'DDL stands for Data Definition Language. It is a subset of SQL (Structured Query Language) used for defining and managing the structure of database objects, such as tables, schemas, and indexesDDL stands for Data Definition Language. It is a subset of SQL used for defining and managing the structure of database objects, such as tables, schemas, and indexes
#
# The CREATE command is used to create new database objects, such as tables, views, or indexes.
# The DROP command is used to delete an existing database object. it will remove the object and all of its data permanently.
#
# The ALTER command is used to modify an existing database object. This can include adding, deleting, or modifying columns in a table, or changing the structure of other object
# The TRUNCATE command is used to delete all rows from a table, but it does not remove the table itself.
# '

# %%
CREATE TABLE Employees (
    EmployeeID INT PRIMARY KEY,
    FirstName VARCHAR(50),
    LastName VARCHAR(50),
    HireDate DATE
);
# Out:
#   Cell In[27], line 1
#     CREATE TABLE Employees (
#            ^
# SyntaxError: invalid syntax

# %%
DROP TABLE Employees;
# Out:
#   Cell In[9], line 1
#     DROP TABLE Employees;
#          ^
# SyntaxError: invalid syntax

# %%
DROP TABLE Employees;
# Out:
#   Cell In[11], line 1
#     DROP TABLE Employees;
#          ^
# SyntaxError: invalid syntax

# %%
TRUNCATE TABLE Employees;
# Out:
#   Cell In[13], line 1
#     TRUNCATE TABLE Employees;
#              ^
# SyntaxError: invalid syntax

# %% [markdown]
# # Q3. What is DML? Explain INSERT, UPDATE, and DELETE with an example.

# %% [raw]
# DML stands for Data Manipulation Language, which is a subset of SQL used to manage and manipulate data within database tables
# The INSERT command is used to add new rows to a table.
# The UPDATE command is used to modify existing data in a table
# The DELETE command is used to remove rows from a table

# %%
INSERT INTO Employees (EmployeeID, FirstName, LastName, HireDate, Email)
VALUES (1, 'John', 'Doe', '2023-01-15', 'john.doe@example.com');
# Out:
#   Cell In[16], line 1
#     INSERT INTO Employees (EmployeeID, FirstName, LastName, HireDate, Email)
#            ^
# SyntaxError: invalid syntax

# %%
UPDATE Employees
SET Email = 'john.newemail@example.com'
WHERE EmployeeID = 1;
# Out:
#   Cell In[25], line 1
#     UPDATE Employees
#            ^
# SyntaxError: invalid syntax

# %%
DELETE FROM Employees
WHERE EmployeeID = 1;

# %% [markdown]
# # Q4. What is DQL? Explain SELECT with an example.

# %% [raw]
# DQL (Data Query Language) is a subset of SQLused to query and retrieve data from a database. It primarily consists of the SELECT statement, which is used to fetch data from one or more tables in a database.

# %%
'The SELECT statement is used to specify the columns of data you want to retrieve from a database table'
SELECT column1, column2
FROM table_name
WHERE condition;

# %% [markdown]
# # Q5. Explain Primary Key and Foreign Key.

# %%
' Primary Key and Foreign Key are fundamental concepts used to establish and enforce relationships between tables. They help maintain data integrity and enable complex queries across multiple tables.'

'A Primary Key is a column or a combination of columns in a table that uniquely identifies each row in that table.'

'A Foreign Key is a column or a set of columns in a table that establishes a link between data in two tables. It refers to the Primary Key in another table, creating a relationship between the two tables.
# Out:
#   Cell In[20], line 5
#     'A Foreign Key is a column or a set of columns in a table that establishes a link between data in two tables. It refers to the Primary Key in another table, creating a relationship between the two tables.
#     ^
# SyntaxError: unterminated string literal (detected at line 5)

# %%
pip install mysql-connector-python
# Out:
# Defaulting to user installation because normal site-packages is not writeableNote: you may need to restart the kernel to use updated packages.
#
# ...
#    ---------------------------------------- 0.0/14.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/14.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/14.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/14.3 MB 245.8 kB/s eta 0:00:59
#    ---------------------------------------- 0.0/14.3 MB 245.8 kB/s eta 0:00:59
#    ---------------------------------------- 0.0/14.3 MB 245.8 kB/s eta 0:00:59
#    ---------------------------------------- 0.1/14.3 MB 217.9 kB/s eta 0:01:06
#    ---------------------------------------- 0.1/14.3 MB 254.2 kB/s eta 0:00:57
#    ---------------------------------------- 0.1/14.3 MB 254.2 kB/s eta 0:00:57
#    ---------------------------------------- 0.1/14.3 MB 218.5 kB/s eta 0:01:06
# ...

# %%
import mysql.connector

# Connect to the database
connection = mysql.connector.connect(
    host="localhost",
    user="your_username",
    password="your_password",
    database="your_database"
)

# Create a cursor object
cursor = connection.cursor()

# Execute a query
query = "SELECT * FROM your_table_name"
cursor.execute(query)

# Fetch all rows from the executed query
rows = cursor.fetchall()

# Print each row
for row in rows:
    print(row)

# Close the cursor and connection
cursor.close()
connection.close()
# Out:
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python311\site-packages\mysql\connector\network.py:758, in MySQLTCPSocket.open_connection(self)
#     757     self.sock.settimeout(self._connection_timeout)
# --> 758     self.sock.connect(sockaddr)
#     759 except IOError as err:
#
# ConnectionRefusedError: [WinError 10061] No connection could be made because the target machine actively refused it
#
# The above exception was the direct cause of the following exception:
#
# InterfaceError                            Traceback (most recent call last)
# Cell In[23], line 4
#       1 import mysql.connector
#       3 # Connect to the database
# ----> 4 connection = mysql.connector.connect(
#       5     host="localhost",
#       6     user="your_username",
#       7     password="your_password",
#       8     database="your_database"
#       9 )
# ...

# %%
'A cursor is an object used to interact with the database. It allows you to execute queries and fetch results.'

'The execute() method is used to execute a SQL query.'
# Out:
# 'The execute() method is used to execute a SQL query.'

# %% [markdown]
# # Q7. Give the order of execution of SQL clauses in an SQL query.

# %%
FROM
WHERE
JOIN
GROUP BY
HAVING
SELECT
