# %% [markdown]
# # 1.What is Matplotlib? Why is it used? Name five plots that can be plotted using the Pyplot module of Matplotlib.

# %%
'''Matplotlib is a vizualization python library.
It use to create static, animated, and interactive visualizations in Python'''

'''five plot's are 
1.scatter plot
2.hist plot
3.bar plot
4.line plot
5.pie plot'''
# Out:
# "five plot's are \n1.scatter plot\n2.hist plot\n3.bar plot\n4.line plot\n5.pie plot"

# %% [markdown]
# # Q2: What is a scatter plot? Use the following code to generate data for x and y. Using this generated data
# plot a scatter plot.

# %%
import numpy as np
import matplotlib.pyplot as plt
np.random.seed(3)

# %%
x= 3+np.random.normal(0,2,50)

# %%
y = 3+np.random.normal(0,2,len(x))

# %%
plt.scatter(x,y)
plt.title('Scatter plot')
plt.xlabel('x-axis')
plt.ylabel('y-axis')
# Out:
# Text(0, 0.5, 'y-axis')

# %% [markdown]
# # Q3: Why is the subplot() function used? Draw four line plots using the subplot() function.

# %%
'''Create axes in tiled positions'''
# Out:
# 'Create axes in tiled positions'

# %%
x = np.array([0, 1, 2, 3, 4, 5]) 
y = np.array([0, 100, 200, 300, 400, 500])
plt.subplot(2,2,2)
plt.plot(x,y)
plt.show()

# %%
x = np.array([0, 1, 2, 3, 4, 5]) 
y = np.array([50, 20, 40, 20, 60, 70])
plt.subplot(1,2,2)
plt.plot(x,y)

# %%
x = np.array([0, 1, 2, 3, 4, 5]) 
y = np.array([10, 20, 30, 40, 50, 60])
plt.subplot(2,3,2)
plt.plot(x,y)

# %%
x = np.array([0, 1, 2, 3, 4, 5])
y = np.array([200, 350, 250, 550, 450, 150])
plt.subplot(2,3,3)
plt.plot(x,y)
plt.show()

# %% [markdown]
# # Q4: What is a bar plot? Why is it used? Using the following data plot a bar plot and a horizontal bar plot.

# %%
'''
bar plot shw relationship between a catagorical and numarical veriable.


'''
# Out:
# '\nbar plot shw relationship between a catagorical and numarical veriable.\n\n\n'

# %%
company = np.array(["Apple", "Microsoft", "Google", "AMD"])
profit = np.array([3000, 8000, 1000, 10000])
c=['r','b','g']
plt.bar(company,profit,color=c)
# Out:
# <BarContainer object of 4 artists>

# %% [markdown]
# # Q5: What is a box plot? Why is it used? Using the following data plot a box plot.

# %%
'''
a box plot and wisker plot aslo called box plot display the five number summary of a set of data.
five number ars are - min, Q1 ,median Q3, max
'''


''' it use to find outliers'''
# Out:
# ' it use to find outliers'

# %%
box1 = np.random.normal(100, 10, 200)

plt.boxplot(box1)
plt.show()

# %%
box2 = np.random.normal(90, 20, 200)
plt.boxplot(box2)
plt.show()
